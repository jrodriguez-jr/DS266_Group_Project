# %% [markdown]
# # Transformer model for detecting misinformation

# %%
pip install mumin[embeddings]
# Out:
# ...
# WARNING: mumin 1.10.0 does not provide the extra 'embeddings'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 14.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 102.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Install Python package, mumin

# %%
# !pip install mumin[all] torchmetrics --quiet
# !pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 8.2 MB/s eta 0:00:00
# WARNING: mumin 1.10.0 does not provide the extra 'all'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 MB 5.6 MB/s eta 0:00:00

# %% [markdown]
# ### Download and compile the MuMin dataset

# %%
# !pip install torch==1.12.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 1.12.0 which is incompatible.
# torchdata 0.7.1 requires torch>=2, but you have torch 1.12.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 1.12.0 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 1.12.0 which is incompatible.
# ...

# %%
# !pip install --upgrade mumin

# %%
from mumin import MuminDataset
from google.colab import drive
from getpass import getpass
from pathlib import Path
import shutil
import re

# %% [markdown]
# ### Initialize dataset

# %% [markdown]
# AAAAAAAAAAAAAAAAAAAAAIOotAEAAAAAflivelAJry7mG9vaXwRbLPVi%2Bx8%3DkEzWMlvWHQIabXhE6MaufyhxVFS7YclgDk9DnaE3ArFTuRsrze

# %%
twitter_bearer_token = getpass('Input Twitter Bearer Token: ')
dataset = MuminDataset(twitter_bearer_token=twitter_bearer_token)
dataset
# Out:
# Input Twitter Bearer Token: ··········
# MuminDataset(size=small, rehydrated=False, compiled=False, bearer_token_available=True)

# %%
dataset.compile()
# Out:
# INFO:mumin.dataset:Downloading dataset
# ...
# INFO:mumin.dataset:Converting dataset to less compressed format
# INFO:mumin.dataset:Loading dataset
# INFO:mumin.dataset:Shrinking dataset
# INFO:mumin.dataset:Rehydrating tweet nodes
# Rehydrating:   0%|          | 0/5261 [00:00<?, ?it/s]
# ERROR:mumin.twitter:[403] b'{"client_id":"28616835","detail":"When authenticating requests to the Twitter API v2 endpoints, you must use keys and tokens from a Twitter developer App that is attached to a Project. You can create a project via the developer portal.","registration_url":"https://developer.twitter.com/en/docs/projects/overview","title":"Client Forbidden","required_enrollment":"Appropriate Level of API Access","reason":"client-not-enrolled","type":"https://api.twitter.com/2/problems/client-forbidden"}'
# ...

# %% [markdown]
# ### Access the data

# %%
from PIL import Image
import itertools as it

# %%
list(dataset.nodes.keys())

# %%
tweet_df = dataset.nodes['tweet']
tweet_df
